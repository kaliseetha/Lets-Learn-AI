# %% [markdown]
# https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb
#
# - Open below notebook in colab
#
# Happy Coding!
#
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kaliseetha/Lets-Learn-AI/blob/main/colab/getting_started_colab_ai.ipynb)

# %%
from google.colab import ai

ai.list_models()
# Out:
# ['google/gemini-2.5-flash', 'google/gemini-2.5-flash-lite']

# %%
# @title Simple batch generation example
# Only text-to-text input/output is supported
from google.colab import ai

response = ai.generate_text("What is the capital of France?")
print(response)
# Out:
# The capital of France is **Paris**.

# %%
# @title Choose a different model
from google.colab import ai

response = ai.generate_text("What is the capital of England", model_name='google/gemini-2.5-flash-lite')
print(response)
# Out:
# The capital of England is **London**.

# %%
# @title Simple streaming example
from google.colab import ai

stream = ai.generate_text("Tell me a short story.", stream=True)
for text in stream:
  print(text, end='')
# Out:
# Arthur Finch lived by the clock, the seasons, and the precise needs of his petunias. Every morning at 6:30 AM, he'd be in his garden, a worn straw hat perched on his head, trowel in hand. His petunias, his roses, his prize-winning marigolds – they were his life’s quiet triumph.
#
# One Tuesday, nestled between a row of vibrant fuchsias and a stubbornly persistent patch of dandelions, Arthur saw it. A seedling, unlike anything he’d ever encountered. Its stem was the colour of moonlight on snow, and its leaves, instead of green, shimmered with a faint, opalescent blue. It felt cool to the touch, almost like polished stone.
#
# Arthur, a man of scientific gardening principles, frowned. He consulted his encyclopedias, his decades of experience. Nothing. He considered plucking it, but a strange curiosity held his hand. He decided to observe.
#
# ...
